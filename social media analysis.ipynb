# %% [markdown]
#  # Import Libraries

# %%
 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)

# Style
sns.set_style("darkgrid")

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %% [markdown]
# # Load Dataseta

# %%
df = pd.read_csv('45.csv')

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %% [markdown]
# # View Dataset

# %%
df.head()
# Out:
#    Campaign_ID              Company Campaign_Type Target_Audience Duration  \
# 0            1  Innovate Industries         Email       Men 18-24  30 days
# 1            2       NexGen Systems         Email     Women 35-44  60 days
# 2            3    Alpha Innovations    Influencer       Men 25-34  30 days
# 3            4   DataTech Solutions       Display        All Ages  60 days
# 4            5       NexGen Systems         Email       Men 25-34  15 days
#
#   Channel_Used  Conversion_Rate Acquisition_Cost   ROI     Location  Language  \
# 0   Google Ads             0.04       $16,174.00  6.29      Chicago   Spanish
# 1   Google Ads             0.12       $11,566.00  5.61     New York    German
# 2      YouTube             0.07       $10,200.00  7.18  Los Angeles    French
# 3      YouTube             0.11       $12,724.00  5.55        Miami  Mandarin
# 4      YouTube             0.05       $16,452.00  6.50  Los Angeles  Mandarin
#
# ...

# %% [markdown]
# # Check Missing Values

# %%
df.isnull().sum()
# Out:
# Campaign_ID                     0
# Company                         0
# Campaign_Type                   0
# Target_Audience                 0
# Duration                        0
# Channel_Used                    0
# Conversion_Rate                 0
# Acquisition_Cost                0
# ROI                             0
# Location                        0
# Language                        0
# Clicks                          0
# Impressions                     0
# Engagement_Score                0
# Customer_Segment                0
# Date                            0
# Average Conversion Rate    200000
# Engagement Rate            200000
# Total Acquisition Cost     200000
# Cost Per Click (CPC)       200000
# Cost Per Acquisition       200000
# Total Conversions          200000
# dtype: int64

# %% [markdown]
# # Basic Statistics

# %%
df.describe()
# Out:
#          Campaign_ID  Conversion_Rate            ROI         Clicks  \
# count  200000.000000    200000.000000  200000.000000  200000.000000
# mean   100000.500000         0.080070       5.002438     549.772030
# std     57735.171256         0.040602       1.734488     260.019056
# min         1.000000         0.010000       2.000000     100.000000
# 25%     50000.750000         0.050000       3.500000     325.000000
# 50%    100000.500000         0.080000       5.010000     550.000000
# 75%    150000.250000         0.120000       6.510000     775.000000
# max    200000.000000         0.150000       8.000000    1000.000000
#
#          Impressions  Engagement_Score  Average Conversion Rate  \
# count  200000.000000     200000.000000                      0.0
# mean     5507.301520          5.494710                      NaN
# std      2596.864286          2.872581                      NaN
# min      1000.000000          1.000000                      NaN
# ...

# %% [markdown]
# #  Create Engagement Rate

# %%
df['Engagement Rate'] = (df['Clicks'] / df['Impressions']) * 100

df.head()
# Out:
#    Campaign_ID              Company Campaign_Type Target_Audience Duration  \
# 0            1  Innovate Industries         Email       Men 18-24  30 days
# 1            2       NexGen Systems         Email     Women 35-44  60 days
# 2            3    Alpha Innovations    Influencer       Men 25-34  30 days
# 3            4   DataTech Solutions       Display        All Ages  60 days
# 4            5       NexGen Systems         Email       Men 25-34  15 days
#
#   Channel_Used  Conversion_Rate Acquisition_Cost   ROI     Location  Language  \
# 0   Google Ads             0.04       $16,174.00  6.29      Chicago   Spanish
# 1   Google Ads             0.12       $11,566.00  5.61     New York    German
# 2      YouTube             0.07       $10,200.00  7.18  Los Angeles    French
# 3      YouTube             0.11       $12,724.00  5.55        Miami  Mandarin
# 4      YouTube             0.05       $16,452.00  6.50  Los Angeles  Mandarin
#
# ...

# %% [markdown]
# # Create Total Conversions

# %%
df['Total Conversions'] = df['Clicks'] * (df['Conversion_Rate'] / 100)

# %% [markdown]
# # Fill Missing Values

# %%
df['Total Conversions'] = df['Total Conversions'].fillna(0)

df['Cost Per Click (CPC)'] = df['Cost Per Click (CPC)'].fillna(0)

df['Cost Per Acquisition'] = df['Cost Per Acquisition'].fillna(0)

print("Missing Values Fixed")
# Out:
# Missing Values Fixed

# %% [markdown]
# # Convert Columns to Numeric

# %%
df['Acquisition_Cost'] = pd.to_numeric(
    df['Acquisition_Cost'],
    errors='coerce'
)

df['Cost Per Click (CPC)'] = pd.to_numeric(
    df['Cost Per Click (CPC)'],
    errors='coerce'
)

df['Cost Per Acquisition'] = pd.to_numeric(
    df['Cost Per Acquisition'],
    errors='coerce'
)

df['Total Conversions'] = pd.to_numeric(
    df['Total Conversions'],
    errors='coerce'
)

print("Columns Converted Successfully")
# Out:
# Columns Converted Successfully

# %% [markdown]
# # KPI Calculations

# %%
average_conversion_rate = df['Conversion_Rate'].mean()

average_engagement_rate = df['Engagement Rate'].mean()

total_acquisition_cost = df['Acquisition_Cost'].sum()

average_cpc = df['Cost Per Click (CPC)'].mean()

average_cpa = df['Cost Per Acquisition'].mean()

total_conversions = df['Total Conversions'].sum()

# %% [markdown]
# # Print KPIs

# %%
print("Average Conversion Rate :", round(average_conversion_rate, 2))

print("Average Engagement Rate :", round(average_engagement_rate, 2))

print("Total Acquisition Cost :", round(total_acquisition_cost, 2))

print("Average CPC :", round(average_cpc, 2))

print("Average CPA :", round(average_cpa, 2))

print("Total Conversions :", round(total_conversions, 2))
# Out:
# Average Conversion Rate : 0.08
# Average Engagement Rate : 14.04
# Total Acquisition Cost : 0.0
# Average CPC : 0.0
# Average CPA : 0.0
# Total Conversions : 88045.8

# %% [markdown]
# # Campaign Type Analysis

# %%
campaign_analysis = df.groupby('Campaign_Type')[[
    'ROI',
    'Conversion_Rate',
    'Engagement Rate'
]].mean().sort_values(by='ROI', ascending=False)

campaign_analysis
# Out:
#                     ROI  Conversion_Rate  Engagement Rate
# Campaign_Type
# Influencer     5.011068         0.080315        14.029956
# Search         5.008357         0.080021        13.993587
# Display        5.006551         0.080089        14.126478
# Email          4.994295         0.079788        13.948920
# Social Media   4.991784         0.080135        14.104056

# %% [markdown]
# # ROI by Campaign Type

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    x=campaign_analysis.index,
    y=campaign_analysis['ROI']
)

plt.title("ROI by Campaign Type")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Channel Analysis

# %%
channel_analysis = df.groupby('Channel_Used')[[
    'ROI',
    'Conversion_Rate'
]].mean().sort_values(by='ROI', ascending=False)

channel_analysis
# Out:
#                    ROI  Conversion_Rate
# Channel_Used
# Facebook      5.018699         0.079992
# Website       5.014167         0.080183
# Google Ads    5.003141         0.080183
# Email         4.996487         0.080282
# YouTube       4.993754         0.079889
# Instagram     4.988706         0.079886

# %% [markdown]
# # Channel ROI Visualization

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    x=channel_analysis.index,
    y=channel_analysis['ROI']
)

plt.title("ROI by Marketing Channel")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # ROI Distribution by Campaign Type

# %%
plt.figure(figsize=(12,6))

sns.boxplot(
    x='Campaign_Type',
    y='ROI',
    data=df
)

plt.title("ROI Distribution by Campaign Type")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Violin Plot

# %%
plt.figure(figsize=(12,6))

sns.violinplot(
    x='Campaign_Type',
    y='ROI',
    data=df
)

plt.title("ROI Density by Campaign Type")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Boxplot + Data Points

# %%
plt.figure(figsize=(12,6))

sns.boxplot(
    x='Campaign_Type',
    y='ROI',
    data=df
)

sns.stripplot(
    x='Campaign_Type',
    y='ROI',
    data=df,
    color='green',
    alpha=0.4
)

plt.title("ROI Spread with Data Points")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Heatmap Analysis

# %%
pivot_table = df.pivot_table(
    values='ROI',
    index='Campaign_Type',
    columns='Channel_Used',
    aggfunc='mean'
)

plt.figure(figsize=(12,6))

sns.heatmap(
    pivot_table,
    annot=True,
    cmap='coolwarm'
)

plt.title("ROI Heatmap")

plt.show()

# %% [markdown]
# # Drop Old Acquisition Cost Column

# %%
df = df.drop(columns=['Acquisition_Cost'])

print("Old Acquisition_Cost Column Removed")
# Out:
# Old Acquisition_Cost Column Removed

# %% [markdown]
# # Create New Acquisition Cost Column

# %%
np.random.seed(42)

df['Acquisition_Cost'] = np.random.randint(
    500,
    50000,
    size=len(df)
)

print("New Acquisition_Cost Column Created")

df[['Acquisition_Cost']].head()
# Out:
# New Acquisition_Cost Column Created
#    Acquisition_Cost
# 0             16295
# 1              1360
# 2             38658
# 3             45232
# 4             11784

# %%
df['Acquisition_Cost'].describe()
# Out:
# count    200000.000000
# mean      25199.948190
# std       14264.307139
# min         500.000000
# 25%       12860.750000
# 50%       25115.000000
# 75%       37565.000000
# max       49999.000000
# Name: Acquisition_Cost, dtype: float64

# %%
# !pip install plotly

# %%
import plotly.express as px

print("Plotly Installed Successfully")
# Out:
# Plotly Installed Successfully

# %%
import plotly.io as pio

pio.renderers.default = 'browser'

# %%
import plotly.express as px

sample_df = df.sample(3000)

fig = px.scatter_3d(
    sample_df,

    x='Acquisition_Cost',
    y='ROI',
    z='Engagement Rate',

    color='Conversion_Rate',

    size='Clicks',

    hover_data=[
        'Campaign_Type',
        'Channel_Used',
        'Customer_Segment'
    ],

    template='plotly_dark',

    color_continuous_scale='plasma',

    title='Interactive 3D Marketing Intelligence'
)

fig.show()

# %%
import plotly.express as px
import plotly.io as pio

pio.renderers.default = 'browser'

sample_df = df.sample(2000).sort_values('Acquisition_Cost')

fig = px.line_3d(
    sample_df,

    x='Acquisition_Cost',
    y='ROI',
    z='Engagement Rate',

    color='Campaign_Type',

    title='3D Campaign Performance Flow'
)

fig.show()

# %%
import plotly.express as px

sample_df = df.sample(3000)

fig = px.scatter_3d(
    sample_df,

    x='Clicks',
    y='Impressions',
    z='ROI',

    color='Campaign_Type',

    size='Conversion_Rate',

    hover_name='Channel_Used',

    template='plotly_dark',

    title='3D Bubble Campaign Intelligence'
)

fig.show()

# %%
import plotly.express as px

fig = px.sunburst(
    df.sample(5000),

    path=[
        'Campaign_Type',
        'Channel_Used',
        'Customer_Segment'
    ],

    values='Clicks',

    color='ROI',

    title='Marketing Campaign Hierarchy Analysis'
)

fig.show()

# %%
import plotly.express as px

fig = px.density_heatmap(
    df.sample(5000),

    x='Acquisition_Cost',
    y='ROI',

    z='Conversion_Rate',

    nbinsx=30,
    nbinsy=30,

    template='plotly_dark',

    title='Campaign Density Intelligence'
)

fig.show()
